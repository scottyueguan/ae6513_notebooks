# %% [markdown]
# # MDP Solver Demonstration
#
# In this exercise, we will first implement the value iteration solver, and then apply it to a simple navigation maze problem.

# %% [markdown]
# ### Step 1: Initialize an MDP environment
#
# In this case, we initialize a maze environment where an agent can navigate to reach a goal state while avoiding obstacles.
